# %% [markdown]
# ## 17.1 컴퓨터 비전

# %%
versioninfo()
# Out:
# Julia Version 1.9.3
# Commit bed2cd540a1 (2023-08-24 14:43 UTC)
# Build Info:
#   Official https://julialang.org/ release
# Platform Info:
#   OS: Linux (x86_64-linux-gnu)
#   CPU: 20 × 12th Gen Intel(R) Core(TM) i7-12700F
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-14.0.6 (ORCJIT, alderlake)
#   Threads: 2 on 20 virtual cores
# Environment:
#   LD_LIBRARY_PATH = :/usr/local/cuda-11.7/lib64

# %%
pwd()
# Out:
# "/home/bread"

# %%
using Pkg

# %%
Pkg.activate("~/test")
# Out:
#   Activating new project at `~/~/test`

# %%
Pkg.instantiate()
# Out:
#    Installed ImageSegmentation ───────── v1.8.1
#    Installed ImageIO ─────────────────── v0.6.6
#    Installed TiffImages ──────────────── v0.6.4
#    Installed OffsetArrays ────────────── v1.12.9
#    Installed TiledIteration ──────────── v0.3.1
#    Installed AxisArrays ──────────────── v0.4.6
#    Installed JpegTurbo ───────────────── v0.1.2
#    Installed PNGFiles ────────────────── v0.3.17
#    Installed Preferences ─────────────── v1.4.0
#    Installed cuDNN ───────────────────── v1.0.3
#    Installed Accessors ───────────────── v0.1.31
#    Installed FFTW ────────────────────── v1.6.0
#    Installed LoggingExtras ───────────── v1.0.0
#    Installed ImageMagick ─────────────── v1.2.1
#    Installed NNlib ───────────────────── v0.8.20
#    Installed GR_jll ──────────────────── v0.72.5+0
#    Installed Xorg_xkbcomp_jll ────────── v1.4.2+4
#    Installed RelocatableFolders ──────── v1.0.0
#    Installed Sixel ───────────────────── v0.1.2
#    Installed Snowball_jll ────────────── v2.2.0+0
#    Installed RegionTrees ─────────────── v0.3.2
#    Installed HTML_Entities ───────────── v1.0.1
#    Installed ConcurrentUtilities ─────── v2.2.0
#    Installed ProgressMeter ───────────── v1.7.2
#    Installed Pidfile ─────────────────── v1.3.0
#    Installed StaticArrays ────────────── v1.5.25
#    Installed OpenEXR ─────────────────── v0.3.2
#    Installed NearestNeighbors ────────── v0.4.13
#    Installed ColorSchemes ────────────── v3.21.0
#    Installed Xorg_libpthread_stubs_jll ─ v0.1.0+3
#    Installed Images ──────────────────── v0.25.2
#    Installed FuncPipelines ───────────── v0.2.3
#    Installed FunctionWrappers ────────── v1.1.3
#    Installed Optimisers ──────────────── v0.2.18
#    Installed GPUArrays ───────────────── v8.6.6
#    Installed TextAnalysis ────────────── v0.7.3
#    Installed IntelOpenMP_jll ─────────── v2023.1.0+0
#    Installed Xorg_libxkbfile_jll ─────── v1.1.0+4
#    Installed HTTP ────────────────────── v1.9.5
#    Installed Netpbm ──────────────────── v1.1.0
#    Installed MetaGraphs ──────────────── v0.7.2
#    Installed ZygoteRules ─────────────── v0.2.3
#    Installed Xorg_libXau_jll ─────────── v1.0.9+4
#    Installed HuggingFaceApi ──────────── v0.1.0
#    Installed Static ──────────────────── v0.8.7
#    Installed DataFrames ──────────────── v1.5.0
#    Installed Distances ───────────────── v0.10.8
#    Installed TupleTools ──────────────── v1.3.0
#    Installed MLUtils ─────────────────── v0.4.2
#    Installed Tricks ──────────────────── v0.1.7
#    Installed JLD2 ────────────────────── v0.4.31
#    Installed MAT ─────────────────────── v0.10.4
#    Installed Fetch ───────────────────── v0.1.4
#    Installed IRTools ─────────────────── v0.4.10
#    Installed AutoHashEquals ──────────── v0.2.0
#    Installed GR ──────────────────────── v0.72.5
#    Installed ArnoldiMethod ───────────── v0.2.0
#    Installed SimpleDraw ──────────────── v0.5.0
#    Installed LLVM ────────────────────── v5.1.0
#    Installed Chemfiles ───────────────── v0.10.40
#    Installed Qt5Base_jll ─────────────── v5.15.3+2
#    Installed DoubleArrayTries ────────── v0.1.0
#    Installed SpecialFunctions ────────── v2.2.0
#    Installed Clustering ──────────────── v0.15.2
#    Installed xkbcommon_jll ───────────── v1.4.1+0
#    Installed Functors ────────────────── v0.4.4
#    Installed SentinelArrays ──────────── v1.3.18
#    Installed BenchmarkTools ──────────── v1.3.2
#    Installed ImageContrastAdjustment ─── v0.3.10
#    Installed GZip ────────────────────── v0.5.1
#    Installed IfElse ──────────────────── v0.1.1
#    Installed PkgVersion ──────────────── v0.3.2
#    Installed QOI ─────────────────────── v1.0.0
#    Installed Metalhead ───────────────── v0.7.4
#    Installed StringEncodings ─────────── v0.3.6
#    Installed StaticArraysCore ────────── v1.4.0
#    Installed OneHotArrays ────────────── v0.2.3
#    Installed TranscodingStreams ──────── v0.9.13
#    Installed fzf_jll ─────────────────── v0.29.0+0
#    Installed BytePairEncoding ────────── v0.3.1
#    Installed UnsafeAtomicsLLVM ───────── v0.1.2
#    Installed Graphs ──────────────────── v1.8.0
#    Installed SnoopPrecompile ─────────── v1.0.3
#    Installed CustomUnitRanges ────────── v1.0.2
#    Installed Graphics ────────────────── v1.1.2
#    Installed ValSplit ────────────────── v0.1.0
#    Installed ImageMetadata ───────────── v0.9.8
#    Installed IJulia ──────────────────── v1.24.0
#    Installed Ratios ──────────────────── v0.4.4
#    Installed CatIndices ──────────────── v0.2.2
#    Installed BufferedStreams ─────────── v1.1.0
#    Installed DataStructures ──────────── v0.18.13
#    Installed FreeType2_jll ───────────── v2.10.4+0
#    Installed JLFzf ───────────────────── v0.1.5
#    Installed ComputationalResources ──── v0.3.2
#    Installed StringViews ─────────────── v1.3.0
#    Installed ExprTools ───────────────── v0.1.9
#    Installed StatsAPI ────────────────── v1.6.0
#    Installed Compat ──────────────────── v4.6.1
#    Installed ImageTransformations ────── v0.9.5
#    Installed ChainRules ──────────────── v1.49.0
#    Installed CodecZlib ───────────────── v0.7.1
#    Installed ImageMagick_jll ─────────── v6.9.12+3
#    Installed StatsBase ───────────────── v0.33.21
#    Installed Xorg_libxcb_jll ─────────── v1.13.0+3
#    Installed Scratch ─────────────────── v1.2.0
#    Installed ImageCore ───────────────── v0.9.4
#    Installed Embeddings ──────────────── v0.4.1
#    Installed Zygote ──────────────────── v0.6.61
#    Installed ImageFiltering ──────────── v0.7.4
#    Installed BangBang ────────────────── v0.3.38
#    Installed Conda ───────────────────── v1.8.0
#    Installed NeuralAttentionlib ──────── v0.2.8
#    Installed PrimitiveOneHot ─────────── v0.1.3
#    Installed JSON3 ───────────────────── v1.12.0
#    Installed CSV ─────────────────────── v0.10.10
#    Installed PrettyTables ────────────── v2.2.4
#    Installed Expat_jll ───────────────── v2.4.8+0
#    Installed Inflate ─────────────────── v0.1.3
#    Installed DataDeps ────────────────── v0.7.10
#    Installed Parsers ─────────────────── v2.5.10
#    Installed ImageShow ───────────────── v0.3.7
#    Installed Imath_jll ───────────────── v3.1.7+0
#    Installed IntegralArrays ──────────── v0.1.5
#    Installed Libtiff_jll ─────────────── v4.4.0+0
#    Installed MKL_jll ─────────────────── v2022.2.0+0
#    Installed PooledArrays ────────────── v1.4.2
#    Installed OhMyArtifacts ───────────── v0.3.1
#    Installed AbstractFFTs ────────────── v1.3.1
#    Installed ConstructionBase ────────── v1.5.2
#    Installed DiffRules ───────────────── v1.13.0
#    Installed ColorVectorSpace ────────── v0.9.10
#    Installed LLVMExtra_jll ───────────── v0.0.21+0
#    Installed OrderedCollections ──────── v1.6.0
#    Installed Plots ───────────────────── v1.38.12
#    Installed Flux ────────────────────── v0.13.16
#    Installed CoordinateTransformations ─ v0.6.3
#    Installed ChainRulesCore ──────────── v1.16.0
#    Installed StrTables ───────────────── v1.0.1
#    Installed ImageQualityIndexes ─────── v0.3.5
#    Installed Ghostscript_jll ─────────── v9.55.0+4
#    Installed LogExpFunctions ─────────── v0.3.23
#    Installed KernelAbstractions ──────── v0.9.4
#    Installed Quaternions ─────────────── v0.7.4
#    Installed HDF5 ────────────────────── v0.16.14
#    Installed PartialFunctions ────────── v1.1.1
#    Installed Rotations ───────────────── v1.5.1
#    Installed FFTW_jll ────────────────── v3.3.10+0
#    Installed MacroTools ──────────────── v0.5.10
#    Installed ObjectDetector ──────────── v0.2.9
#    Installed RangeArrays ─────────────── v0.3.2
#    Installed Snowball ────────────────── v0.1.0
#    Installed UnPack ──────────────────── v1.0.2
#    Installed OpenEXR_jll ─────────────── v3.1.4+0
#    Installed GPUArraysCore ───────────── v0.1.4
#    Installed Adapt ───────────────────── v3.6.2
#    Installed Pixman_jll ──────────────── v0.40.1+0
#    Installed XML2_jll ────────────────── v2.10.3+0
#    Installed ImageBase ───────────────── v0.1.5
#    Installed Interpolations ──────────── v0.14.7
#    Installed IntervalSets ────────────── v0.7.4
#    Installed StructWalk ──────────────── v0.2.1
#    Installed Wayland_jll ─────────────── v1.21.0+0
#    Installed IterTools ───────────────── v1.4.0
#    Installed Xorg_xtrans_jll ─────────── v1.4.0+3
#    Installed OpenSSL_jll ─────────────── v1.1.20+0
#    Installed FoldsThreads ────────────── v0.1.1
#    Installed IndirectArrays ──────────── v1.0.0
#    Installed InverseFunctions ────────── v0.1.9
#    Installed Tables ──────────────────── v1.10.1
#    Installed SimpleWeightedGraphs ────── v1.4.0
#    Installed Languages ───────────────── v0.4.3
#    Installed Xorg_xkeyboard_config_jll ─ v2.27.0+4
#    Installed ImageDistances ──────────── v0.2.16
#    Installed Libiconv_jll ────────────── v1.16.1+2
#    Installed PrecompileTools ─────────── v1.1.1
#    Installed URIs ────────────────────── v1.4.2
#    Installed StructArrays ────────────── v0.6.15
#    Installed LaTeXStrings ────────────── v1.3.0
#    Installed Glib_jll ────────────────── v2.74.0+2
#    Installed libsixel_jll ────────────── v1.10.3+0
#    Installed FilePathsBase ───────────── v0.9.20
#    Installed GPUCompiler ─────────────── v0.19.4
#    Installed Transducers ─────────────── v0.4.76
#    Installed MLDatasets ──────────────── v0.7.9
#    Installed FillArrays ──────────────── v1.0.1
#    Installed ForwardDiff ─────────────── v0.10.35
#    Installed Transformers ────────────── v0.2.4
#    Installed AxisAlgorithms ──────────── v1.0.1
#    Installed Xorg_libXdmcp_jll ───────── v1.1.3+4
#    Installed ImageAxes ───────────────── v0.6.10
#    Installed FFTViews ────────────────── v0.3.2
#    Installed Xorg_libX11_jll ─────────── v1.6.9+4
#    Installed Latexify ────────────────── v0.16.0
#    Installed LightXML ────────────────── v0.9.0
#    Installed Parameters ──────────────── v0.12.3
#    Installed ImageMorphology ─────────── v0.3.2
#    Installed CUDNN_jll ───────────────── v8.8.1+0
#    Installed SortingAlgorithms ───────── v1.1.0
#    Installed WoodburyMatrices ────────── v0.5.5
#    Installed StringManipulation ──────── v0.3.0
#    Installed Pickle ──────────────────── v0.3.2
#    Installed ImageDraw ───────────────── v0.2.5
#    Installed TextEncodeBase ──────────── v0.6.0
#    Installed WordTokenizers ──────────── v0.5.6
#    Installed CUDA ────────────────────── v4.2.0
#     Building Conda ────────→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/e32a90da027ca45d84678b826fffd3110bb3fc90/build.log`
#     Building HTML_Entities → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/c4144ed3bc5f67f595622ad03c0e39fa6c70ccc7/build.log`
#     Building HDF5 ─────────→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/3dab31542b3da9f25a6a1d11159d4af8fdce7d67/build.log`
#     Building IJulia ───────→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/59e19713542dd9dd02f31d59edbada69530d6a14/build.log`
# Precompiling project...
#   ✓ Tricks
#   ✓ IndirectArrays
#   ✓ StrTables
#   ✓ UnPack
#   ✓ StatsAPI
#   ✓ RangeArrays
#   ✓ LaTeXStrings
#   ✓ FuncPipelines
#   ✓ ExprTools
#   ✓ AbstractFFTs
#   ✓ InverseFunctions
#   ✓ StringViews
#   ✓ ConcurrentUtilities
#   ✓ FunctionWrappers
#   ✓ PartialFunctions
#   ✓ BufferedStreams
#   ✓ WoodburyMatrices
#   ✓ IterTools
#   ✓ Compat
#   ✓ PkgVersion
#   ✓ AutoHashEquals
#   ✓ Pidfile
#   ✓ CustomUnitRanges
#   ✓ OrderedCollections
#   ✓ Preferences
#   ✓ IntervalSets
#   ✓ URIs
#   ✓ SentinelArrays
#   ✓ ProgressMeter
#   ✓ IfElse
#   ✓ Ratios
#   ✓ Inflate
#   ✓ Scratch
#   ✓ TranscodingStreams
#   ✓ ConstructionBase
#   ✓ Adapt
#   ✓ LoggingExtras
#   ✓ ComputationalResources
#   ✓ LogExpFunctions
#   ✓ StaticArraysCore
#   ✓ TupleTools
#   ✓ Quaternions
#   ✓ GZip
#   ✓ PooledArrays
#   ✓ Functors
#   ✓ Graphics
#   ✓ HTML_Entities
#   ✓ FillArrays
#   ✓ ValSplit
#   ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ✓ StringManipulation
#   ✓ Distances
#   ✓ Compat → CompatLinearAlgebraExt
#   ✓ AxisAlgorithms
#   ✓ QOI
#   ✓ SimpleDraw
#   ✓ Parameters
#   ✓ MacroTools
#   ✓ SnoopPrecompile
#   ✓ PrecompileTools
#   ✓ JLLWrappers
#   ✓ RelocatableFolders
#   ✓ Ratios → RatiosFixedPointNumbersExt
#   ✓ IntegralArrays
#   ✓ OhMyArtifacts
#   ✓ Static
#   ✓ AxisArrays
#   ✓ Tables
#   ✓ ConstructionBase → ConstructionBaseIntervalSetsExt
#   ✓ LogExpFunctions → LogExpFunctionsInverseFunctionsExt
#   ✓ CodecZlib
#   ✓ StructWalk
#   ✓ DiffResults
#   ✓ ContextVariablesX
#   ✓ CommonSubexpressions
#   ✓ FilePathsBase
#   ✓ OpenSSL_jll
#   ✓ Strided
#   ✓ SimpleTraits
#   ✓ Graphite2_jll
#   ✓ CUDA_Driver_jll
#   ✓ Libmount_jll
#   ✓ Bzip2_jll
#   ✓ libsodium_jll
#   ✓ ChainRulesCore
#   ✓ Chemfiles_jll
#   ✓ IRTools
#   ✓ Ghostscript_jll
#   ✓ Imath_jll
#   ✓ Xorg_libXau_jll
#   ✓ libpng_jll
#   ✓ libfdk_aac_jll
#   ✓ IntelOpenMP_jll
#   ✓ LAME_jll
#   ✓ TimerOutputs
#   ✓ Pixman_jll
#   ✓ DataStructures
#   ✓ LERC_jll
#   ✓ fzf_jll
#   ✓ RecipesBase
#   ✓ JpegTurbo_jll
#   ✓ x265_jll
#   ✓ Xorg_libXdmcp_jll
#   ✓ Ogg_jll
#   ✓ x264_jll
#   ✓ Zstd_jll
#   ✓ Expat_jll
#   ✓ LZO_jll
#   ✓ libaom_jll
#   ✓ Opus_jll
#   ✓ Libiconv_jll
#   ✓ Xorg_xtrans_jll
#   ✓ Libffi_jll
#   ✓ Libgpg_error_jll
#   ✓ Snowball_jll
#   ✓ LLVMExtra_jll
#   ✓ Wayland_protocols_jll
#   ✓ FFTW_jll
#   ✓ OpenSpecFun_jll
#   ✓ Xorg_libpthread_stubs_jll
#   ✓ Libuuid_jll
#   ✓ FriBidi_jll
#   ✓ FLoopsBase
#   ✓ FreeType2_jll
#   ✓ HDF5_jll
#   ✓ ZeroMQ_jll
#   ✓ AbstractFFTs → AbstractFFTsChainRulesCoreExt
#   ✓ OpenEXR_jll
#   ✓ Latexify
#   ✓ ZygoteRules
#   ✓ CUDA_Runtime_jll
#   ✓ MKL_jll
#   ✓ SortingAlgorithms
#   ✓ Optimisers
#   ✓ JLFzf
#   ✓ libsixel_jll
#   ✓ LogExpFunctions → LogExpFunctionsChainRulesCoreExt
#   ✓ StringEncodings
#   ✓ libvorbis_jll
#   ✓ Libgcrypt_jll
#   ✓ Libtiff_jll
#   ✓ Chemfiles
#   ✓ XML2_jll
#   ✓ Fontconfig_jll
#   ✓ CUDNN_jll
#   ✓ OpenSSL
#   ✓ ImageMagick_jll
#   ✓ LightXML
#   ✓ OpenEXR
#   ✓ ZMQ
#   ✓ XSLT_jll
#   ✓ Gettext_jll
#   ✓ Wayland_jll
#   ✓ StatsBase
#   ✓ Glib_jll
#   ✓ Xorg_libxcb_jll
#   ✓ Xorg_xcb_util_jll
#   ✓ Xorg_libX11_jll
#   ✓ StaticArrays
#   ✓ Pickle
#   ✓ Xorg_libXext_jll
#   ✓ Xorg_xcb_util_renderutil_jll
#   ✓ Xorg_xcb_util_image_jll
#   ✓ Xorg_xcb_util_keysyms_jll
#   ✓ Xorg_libXrender_jll
#   ✓ Xorg_libXfixes_jll
#   ✓ Xorg_xcb_util_wm_jll
#   ✓ Xorg_libxkbfile_jll
#   ✓ HTTP
#   ✓ SpecialFunctions
#   ✓ ConstructionBase → ConstructionBaseStaticArraysExt
#   ✓ Libglvnd_jll
#   ✓ Xorg_libXinerama_jll
#   ✓ Adapt → AdaptStaticArraysExt
#   ✓ Cairo_jll
#   ✓ RegionTrees
#   ✓ Xorg_libXcursor_jll
#   ✓ CoordinateTransformations
#   ✓ Xorg_libXrandr_jll
#   ✓ LLVM
#   ✓ ArnoldiMethod
#   ✓ Xorg_libXi_jll
#   ✓ Xorg_xkbcomp_jll
#   ✓ DiffRules
#   ✓ Rotations
#   ✓ GPUArraysCore
#   ✓ HarfBuzz_jll
#   ✓ NearestNeighbors
#   ✓ DataDeps
#   ✓ SpecialFunctions → SpecialFunctionsChainRulesCoreExt
#   ✓ OffsetArrays
#   ✓ Setfield
#   ✓ GLFW_jll
#   ✓ Xorg_xkeyboard_config_jll
#   ✓ Accessors
#   ✓ StructArrays
#   ✓ libass_jll
#   ✓ UnsafeAtomicsLLVM
#   ✓ GPUArrays
#   ✓ StackViews
#   ✓ CatIndices
#   ✓ TiledIteration
#   ✓ ColorVectorSpace
#   ✓ PaddedViews
#   ✓ HDF5
#   ✓ Clustering
#   ✓ DoubleArrayTries
#   ✓ SplittablesBase
#   ✓ Embeddings
#   ✓ BangBang
#   ✓ Accessors → AccessorsIntervalSetsExt
#   ✓ xkbcommon_jll
#   ✓ Graphs
#   ✓ ForwardDiff
#   ✓ Accessors → AccessorsStructArraysExt
#   ✓ WordTokenizers
#   ✓ Accessors → AccessorsStaticArraysExt
#   ✓ MosaicViews
#   ✓ Interpolations
#   ✓ FFMPEG_jll
#   ✓ BangBang → BangBangStructArraysExt
#   ✓ BangBang → BangBangChainRulesCoreExt
#   ✓ MAT
#   ✓ Qt5Base_jll
#   ✓ FFMPEG
#   ✓ BangBang → BangBangStaticArraysExt
#   ✓ ForwardDiff → ForwardDiffStaticArraysExt
#   ✓ SimpleWeightedGraphs
#   ✓ GR_jll
#   ✓ PrettyTables
#   ✓ KernelAbstractions
#   ✓ ColorSchemes
#   ✓ ChainRules
#   ✓ NNlib
#   ✓ FFTW
#   ✓ FFTViews
#   ✓ PrimitiveOneHot
#   ✓ OneHotArrays
#   ✓ TextEncodeBase
#   ✓ BytePairEncoding
#   ✓ JLD2
#   ✓ Parsers
#   ✓ InlineStrings
#   ✓ MetaGraphs
#   ✓ WeakRefStrings
#   ✓ JSON
#   ✓ Conda
#   ✓ PlotUtils
#   ✓ BenchmarkTools
#   ✓ Languages
#   ✓ IJulia
#   ✓ Snowball
#   ✓ JSON3
#   ✓ PlotThemes
#   ✓ GR
#   ✓ Fetch
#   ✓ HuggingFaceApi
#   ✓ RecipesPipeline
#   ✓ TextAnalysis
#   ✓ GPUCompiler
#   ✓ ImageCore
#   ✓ CSV
#   ✓ ImageDraw
#   ✓ JpegTurbo
#   ✓ Sixel
#   ✓ ImageMorphology
#   ✓ ImageBase
#   ✓ ImageDistances
#   ✓ ImageMagick
#   ✓ PNGFiles
#   ✓ ImageShow
#   ✓ ImageAxes
#   ✓ TiffImages
#   ✓ ImageTransformations
#   ✓ ImageMetadata
#   ✓ Netpbm
#   ✓ ImageContrastAdjustment
#   ✓ ImageIO
#   ✓ Zygote
#   ✓ Zygote → ZygoteColorsExt
#   ✓ Zygote → ZygoteDistancesExt
#   ✓ DataFrames
#   ✓ Latexify → DataFramesExt
#   ✓ BangBang → BangBangDataFramesExt
#   ✓ MicroCollections
#   ✓ Transducers
#   ✓ FoldsThreads
#   ✓ FLoops
#   ✓ MLUtils
#   ✓ MLDatasets
#   ✓ CUDA
#   ✓ cuDNN
#   ✓ ImageFiltering
#   ✓ NNlibCUDA
#   ✓ ImageSegmentation
#   ✓ NeuralAttentionlib
#   ✓ Flux
#   ✓ ImageQualityIndexes
#   ✓ Images
#   ✓ Metalhead
#   ✓ Transformers
#   ✓ ObjectDetector
#   ✓ Plots
#   ✓ Plots → FileIOExt
#   ✓ Plots → IJuliaExt
#   305 dependencies successfully precompiled in 98 seconds. 67 already precompiled.
#   10 dependencies precompiled but different versions are currently loaded. Restart julia to access the new versions
#   2 dependencies had warnings during precompilation:
# ┌ Snowball [fb8f903a-0164-4e73-9ffe-431110250c3b]
# │  WARNING: method definition for stem_all at /home/bread/.julia/packages/Snowball/Ibzfl/src/Snowball.jl:89 declares type variable S but does not use it.
# └
# ┌ TextAnalysis [a2db99b7-8b79-58f8-94bf-bbc811eef33d]
# │  WARNING: method definition for #CooMatrix#80 at /home/bread/.julia/packages/TextAnalysis/B0QxG/src/coom.jl:148 declares type variable T but does not use it.
# └

# %%
import MLDatasets 
import Flux, NNlib 
import Flux: onehotbatch 
import MLUtils: DataLoader 
import CUDA: has_cuda 
import Zygote, Optimisers 
import Formatting: printfmtln
using Random: MersenneTwister
import Plots
# 필요 데이터 자동 다운로드
ENV["DATADEPS_ALWAYS_ACCEPT"] = true;
# Out:
# [ Info: Precompiling MLDatasets [eb30cadb-4394-5ae3-aed4-317e484a6458]
# [ Info: Precompiling Flux [587475ba-b771-5e3f-ad9e-33799f191a9c]
# [ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# [ Info: Precompiling ZygoteColorsExt [e68c091a-8ea5-5ca7-be4f-380657d4ad79]
# [ Info: Precompiling FileIOExt [f5f51d8f-5827-5d2e-939b-192fcd6ec70c]
# [ Info: Precompiling IJuliaExt [2f4121a4-3b3a-5ce6-9c5e-1f2673ce168a]

# %%
function get_data(batchsize = 64)
    xtrain, ytrain = MLDatasets.FashionMNIST(:train)[:]
    xtest, ytest = MLDatasets.FashionMNIST(:test)[:]

    xtrain = reshape(xtrain, 28, 28, 1, :)
    xtest = reshape(xtest, 28, 28, 1, :)

    ytrain, ytest = onehotbatch(ytrain, 0:9), onehotbatch(ytest, 0:9)

    train_loader = DataLoader((xtrain, ytrain), batchsize=batchsize)
    test_loader = DataLoader((xtest, ytest),  batchsize=batchsize)
    
    return train_loader, test_loader
end

function train(loader, model, loss_fn, optimizer)
    num_batches = length(loader)
    losses = Float32[]
    Flux.testmode!(model, false)
    for (batch, (X, y)) in enumerate(loader)
        X, y = Flux.gpu(X), Flux.gpu(y)
        grad = Zygote.gradient(m -> loss_fn(m, X, y), model)[1]
        optimizer, model = Optimisers.update(optimizer, model, grad)
        if batch % 300 == 0
            loss = loss_fn(model, X, y)
            printfmtln("[Train] loss: {:.7f} [{:>3d}/{:>3d}]", 
                loss, batch, num_batches)
            push!(losses, loss)
        end
    end
    model, optimizer, losses
end

function test(loader, model, loss_fn)
    num_batches = length(loader)
    Flux.testmode!(model, true)
    acc, tot = 0, 0
    loss = 0f0
    for (X, y) in loader
        X, y = Flux.gpu(X), Flux.gpu(y)
        pred = model(X)
        acc += sum(Flux.onecold(pred) .== Flux.onecold(y))
        tot += size(X)[end]
        loss += loss_fn(model, X, y)
    end
    acc, avg_loss = acc / tot * 100, loss / num_batches
    printfmtln("[Test] Accuracy: {:.1f}, Avg loss: {:.7f}", 
        acc, avg_loss)
    acc, avg_loss
end

init(rng) = Flux.glorot_uniform(rng)

function build_mlp_model(rng)
    Flux.Chain(
        Flux.flatten,
        Flux.Dense(28 * 28 => 512, NNlib.relu; init=init(rng)),
        Flux.Dense(512 => 512, NNlib.relu; init=init(rng)),
        Flux.Dense(512 => 10; init=init(rng)),
    )
end
# Out:
# build_mlp_model (generic function with 1 method)

# %%
function build_cnn_model(rng)
    same = Flux.SamePad()
    Flux.Chain(
        Flux.Conv((3,3),  1 => 32, NNlib.relu, pad=same; init=init(rng)),
        Flux.MaxPool((2,2)), # (28 x 28) => (14 x 14)
        Flux.Conv((3,3), 32 => 64, NNlib.relu, pad=same; init=init(rng)),
        Flux.MaxPool((2,2)), # (14 x 14) => (7 x 7)
        Flux.Conv((3,3), 64 => 64, NNlib.relu, pad=same; init=init(rng)),
        Flux.MaxPool((2,2)), # (7 x 7) => (3 x 3)
        Flux.flatten,
        Flux.Dense(3 * 3 * 64 => 64, NNlib.relu; init=init(rng)),
        Flux.Dense(64 => 10; init=init(rng)),
    )
end
# Out:
# build_cnn_model (generic function with 1 method)

# %%
function build_cnn2_model(rng)
    same = Flux.SamePad()
    Flux.Chain(
        Flux.Conv((3,3),  1 => 32, NNlib.relu, pad=same; init=init(rng)),
        Flux.MaxPool((2,2)), # (28 x 28) => (14 x 14)
        Flux.Dropout(0.2),
        Flux.BatchNorm(32),

        Flux.Conv((3,3), 32 => 64, NNlib.relu, pad=same; init=init(rng)),
        Flux.MaxPool((2,2)), # (14 x 14) => (7 x 7)
        Flux.Dropout(0.2),
        Flux.BatchNorm(64),
        
        Flux.Conv((3,3), 64 => 64, NNlib.relu, pad=same; init=init(rng)),
        Flux.MaxPool((2,2)), # (7 x 7) => (3 x 3)        
        Flux.Dropout(0.2),
        Flux.BatchNorm(64),
        
        Flux.flatten,
        Flux.Dense(3 * 3 * 64 => 64, NNlib.relu; init=init(rng)),    
        Flux.Dropout(0.2),
        Flux.Dense(64 => 10; init=init(rng)),
    )
end
# Out:
# build_cnn2_model (generic function with 1 method)

# %%
function run_batch(loaders, models, epochs)
    train_loader, test_loader = loaders
    loss_fn(m, x, y) = Flux.Losses.logitcrossentropy(m(x), y)
    train_losses, accuracies = [], []
    for (k, model) in enumerate(models)
        train_loss, accuracy = [], []
        optimizer = Optimisers.setup(Optimisers.Adam(), model)
        for t in 1:epochs
            println("[Model $k] Epochs $t")
            println("-------------------------------")
            model, optimizer, losses = train(train_loader, model, loss_fn, optimizer)
            train_loss = vcat(train_loss, losses)
            acc, _ = test(test_loader, model, loss_fn)
            push!(accuracy, acc)
        ends
        push!(train_losses, train_loss)
        push!(accuracies, accuracy)
    end
    train_losses, accuracies
end
# Out:
# run_batch (generic function with 1 method)

# %%
rng = MersenneTwister(1)
models = [build_mlp_model(rng), build_cnn_model(rng), build_cnn2_model(rng)] 
models = models .|> Flux.gpu

epochs = 25
# Out:
# 25

# %%
train_losses, accuracies = run_batch(get_data(), models, epochs);
# Out:
# [Model 1] Epochs 1
# -------------------------------
# [Train] loss: 0.3187818 [300/938]
# [Train] loss: 0.3166133 [600/938]
# [Train] loss: 0.2775359 [900/938]
# [Test] Accuracy: 85.8, Avg loss: 0.3922605
# [Model 1] Epochs 2
# -------------------------------
# [Train] loss: 0.2442732 [300/938]
# [Train] loss: 0.2580682 [600/938]
# [Train] loss: 0.2255096 [900/938]
# [Test] Accuracy: 85.8, Avg loss: 0.3781293
# [Model 1] Epochs 3
# -------------------------------
# [Train] loss: 0.2108830 [300/938]
# [Train] loss: 0.2265940 [600/938]
# [Train] loss: 0.1910192 [900/938]
# [Test] Accuracy: 86.1, Avg loss: 0.3755460
# [Model 1] Epochs 4
# -------------------------------
# [Train] loss: 0.2409140 [300/938]
# [Train] loss: 0.2238099 [600/938]
# [Train] loss: 0.1754796 [900/938]
# [Test] Accuracy: 86.4, Avg loss: 0.3708964
# [Model 1] Epochs 5
# -------------------------------
# [Train] loss: 0.1761816 [300/938]
# [Train] loss: 0.1893534 [600/938]
# [Train] loss: 0.1520506 [900/938]
# [Test] Accuracy: 86.7, Avg loss: 0.3566868
# [Model 1] Epochs 6
# -------------------------------
# [Train] loss: 0.2148521 [300/938]
# [Train] loss: 0.1740525 [600/938]
# [Train] loss: 0.1227385 [900/938]
# [Test] Accuracy: 87.0, Avg loss: 0.3617811
# [Model 1] Epochs 7
# -------------------------------
# [Train] loss: 0.2035912 [300/938]
# [Train] loss: 0.1679572 [600/938]
# [Train] loss: 0.1208432 [900/938]
# [Test] Accuracy: 87.3, Avg loss: 0.3588105
# [Model 1] Epochs 8
# -------------------------------
# [Train] loss: 0.1799067 [300/938]
# [Train] loss: 0.1142531 [600/938]
# [Train] loss: 0.0907502 [900/938]
# [Test] Accuracy: 88.0, Avg loss: 0.3422290
# [Model 1] Epochs 9
# -------------------------------
# [Train] loss: 0.1676266 [300/938]
# [Train] loss: 0.1211139 [600/938]
# [Train] loss: 0.0849616 [900/938]
# [Test] Accuracy: 87.6, Avg loss: 0.3570665
# [Model 1] Epochs 10
# -------------------------------
# [Train] loss: 0.1527912 [300/938]
# [Train] loss: 0.1124074 [600/938]
# [Train] loss: 0.0816490 [900/938]
# [Test] Accuracy: 87.7, Avg loss: 0.3654638
# [Model 1] Epochs 11
# -------------------------------
# [Train] loss: 0.1407414 [300/938]
# [Train] loss: 0.0989472 [600/938]
# [Train] loss: 0.0725007 [900/938]
# [Test] Accuracy: 87.9, Avg loss: 0.3685654
# [Model 1] Epochs 12
# -------------------------------
# [Train] loss: 0.1486202 [300/938]
# [Train] loss: 0.1093680 [600/938]
# [Train] loss: 0.0620999 [900/938]
# [Test] Accuracy: 88.0, Avg loss: 0.3855948
# [Model 1] Epochs 13
# -------------------------------
# [Train] loss: 0.1532752 [300/938]
# [Train] loss: 0.1241962 [600/938]
# [Train] loss: 0.0428764 [900/938]
# [Test] Accuracy: 87.4, Avg loss: 0.4166348
# [Model 1] Epochs 14
# -------------------------------
# [Train] loss: 0.1253905 [300/938]
# [Train] loss: 0.1089442 [600/938]
# [Train] loss: 0.0499833 [900/938]
# [Test] Accuracy: 87.6, Avg loss: 0.4081634
# [Model 1] Epochs 15
# -------------------------------
# [Train] loss: 0.1263865 [300/938]
# [Train] loss: 0.0872053 [600/938]
# [Train] loss: 0.0349652 [900/938]
# [Test] Accuracy: 86.6, Avg loss: 0.4687523
# [Model 1] Epochs 16
# -------------------------------
# [Train] loss: 0.1188506 [300/938]
# [Train] loss: 0.0797579 [600/938]
# [Train] loss: 0.0581011 [900/938]
# [Test] Accuracy: 87.8, Avg loss: 0.4188649
# [Model 1] Epochs 17
# -------------------------------
# [Train] loss: 0.1324126 [300/938]
# [Train] loss: 0.0931191 [600/938]
# [Train] loss: 0.0316588 [900/938]
# [Test] Accuracy: 87.4, Avg loss: 0.4479318
# [Model 1] Epochs 18
# -------------------------------
# [Train] loss: 0.1109607 [300/938]
# [Train] loss: 0.0876729 [600/938]
# [Train] loss: 0.0356437 [900/938]
# [Test] Accuracy: 87.5, Avg loss: 0.4562132
# [Model 1] Epochs 19
# -------------------------------
# [Train] loss: 0.1216706 [300/938]
# [Train] loss: 0.0793577 [600/938]
# [Train] loss: 0.0341102 [900/938]
# [Test] Accuracy: 87.8, Avg loss: 0.4688709
# [Model 1] Epochs 20
# -------------------------------
# [Train] loss: 0.0830693 [300/938]
# [Train] loss: 0.0649461 [600/938]
# [Train] loss: 0.0294848 [900/938]
# [Test] Accuracy: 87.9, Avg loss: 0.4895078
# [Model 1] Epochs 21
# -------------------------------
# [Train] loss: 0.0741556 [300/938]
# [Train] loss: 0.0553922 [600/938]
# [Train] loss: 0.0304674 [900/938]
# [Test] Accuracy: 88.2, Avg loss: 0.4772334
# [Model 1] Epochs 22
# -------------------------------
# [Train] loss: 0.0864997 [300/938]
# [Train] loss: 0.0626929 [600/938]
# [Train] loss: 0.0204048 [900/938]
# [Test] Accuracy: 88.1, Avg loss: 0.5080673
# [Model 1] Epochs 23
# -------------------------------
# [Train] loss: 0.0728427 [300/938]
# [Train] loss: 0.0388895 [600/938]
# [Train] loss: 0.0259850 [900/938]
# [Test] Accuracy: 88.5, Avg loss: 0.4764910
# [Model 1] Epochs 24
# -------------------------------
# [Train] loss: 0.1092009 [300/938]
# [Train] loss: 0.0728353 [600/938]
# [Train] loss: 0.0174233 [900/938]
# [Test] Accuracy: 88.3, Avg loss: 0.5378468
# [Model 1] Epochs 25
# -------------------------------
# [Train] loss: 0.0993168 [300/938]
# [Train] loss: 0.0620704 [600/938]
# [Train] loss: 0.0445310 [900/938]
# [Test] Accuracy: 87.8, Avg loss: 0.5367583
# [Model 2] Epochs 1
# -------------------------------
# [Train] loss: 0.3802364 [300/938]
# [Train] loss: 0.3698740 [600/938]
# [Train] loss: 0.2809396 [900/938]
# [Test] Accuracy: 86.6, Avg loss: 0.3759279
# [Model 2] Epochs 2
# -------------------------------
# [Train] loss: 0.2521951 [300/938]
# [Train] loss: 0.2006202 [600/938]
# [Train] loss: 0.1840870 [900/938]
# [Test] Accuracy: 87.5, Avg loss: 0.3424533
# [Model 2] Epochs 3
# -------------------------------
# [Train] loss: 0.1910513 [300/938]
# [Train] loss: 0.1412161 [600/938]
# [Train] loss: 0.1208253 [900/938]
# [Test] Accuracy: 88.1, Avg loss: 0.3262222
# [Model 2] Epochs 4
# -------------------------------
# [Train] loss: 0.1995536 [300/938]
# [Train] loss: 0.1068432 [600/938]
# [Train] loss: 0.0918837 [900/938]
# [Test] Accuracy: 88.6, Avg loss: 0.3053244
# [Model 2] Epochs 5
# -------------------------------
# [Train] loss: 0.1819970 [300/938]
# [Train] loss: 0.0800835 [600/938]
# [Train] loss: 0.0719322 [900/938]
# [Test] Accuracy: 89.1, Avg loss: 0.2974638
# [Model 2] Epochs 6
# -------------------------------
# [Train] loss: 0.1619029 [300/938]
# [Train] loss: 0.0654245 [600/938]
# [Train] loss: 0.0665660 [900/938]
# [Test] Accuracy: 89.4, Avg loss: 0.2897014
# [Model 2] Epochs 7
# -------------------------------
# [Train] loss: 0.1667324 [300/938]
# [Train] loss: 0.0557909 [600/938]
# [Train] loss: 0.0569368 [900/938]
# [Test] Accuracy: 89.5, Avg loss: 0.2953879
# [Model 2] Epochs 8
# -------------------------------
# [Train] loss: 0.1864012 [300/938]
# [Train] loss: 0.0459318 [600/938]
# [Train] loss: 0.0559602 [900/938]
# [Test] Accuracy: 89.5, Avg loss: 0.2942436
# [Model 2] Epochs 9
# -------------------------------
# [Train] loss: 0.1719853 [300/938]
# [Train] loss: 0.0438754 [600/938]
# [Train] loss: 0.0505878 [900/938]
# [Test] Accuracy: 89.6, Avg loss: 0.3143062
# [Model 2] Epochs 10
# -------------------------------
# [Train] loss: 0.1181640 [300/938]
# [Train] loss: 0.0382726 [600/938]
# [Train] loss: 0.0550838 [900/938]
# [Test] Accuracy: 90.0, Avg loss: 0.3166807
# [Model 2] Epochs 11
# -------------------------------
# [Train] loss: 0.1530777 [300/938]
# [Train] loss: 0.0375617 [600/938]
# [Train] loss: 0.0232738 [900/938]
# [Test] Accuracy: 90.3, Avg loss: 0.3217429
# [Model 2] Epochs 12
# -------------------------------
# [Train] loss: 0.0808817 [300/938]
# [Train] loss: 0.0299992 [600/938]
# [Train] loss: 0.0172547 [900/938]
# [Test] Accuracy: 90.4, Avg loss: 0.3409197
# [Model 2] Epochs 13
# -------------------------------
# [Train] loss: 0.0701030 [300/938]
# [Train] loss: 0.0233961 [600/938]
# [Train] loss: 0.0178103 [900/938]
# [Test] Accuracy: 90.3, Avg loss: 0.3820737
# [Model 2] Epochs 14
# -------------------------------
# [Train] loss: 0.0373186 [300/938]
# [Train] loss: 0.0185366 [600/938]
# [Train] loss: 0.0143690 [900/938]
# [Test] Accuracy: 90.4, Avg loss: 0.4067464
# [Model 2] Epochs 15
# -------------------------------
# [Train] loss: 0.0446521 [300/938]
# [Train] loss: 0.0129007 [600/938]
# [Train] loss: 0.0064889 [900/938]
# [Test] Accuracy: 90.5, Avg loss: 0.4065623
# [Model 2] Epochs 16
# -------------------------------
# [Train] loss: 0.0429684 [300/938]
# [Train] loss: 0.0225000 [600/938]
# [Train] loss: 0.0042328 [900/938]
# [Test] Accuracy: 90.3, Avg loss: 0.4169698
# [Model 2] Epochs 17
# -------------------------------
# [Train] loss: 0.0461415 [300/938]
# [Train] loss: 0.0286320 [600/938]
# [Train] loss: 0.0066912 [900/938]
# [Test] Accuracy: 90.7, Avg loss: 0.4117146
# [Model 2] Epochs 18
# -------------------------------
# [Train] loss: 0.0269404 [300/938]
# [Train] loss: 0.0102829 [600/938]
# [Train] loss: 0.0053948 [900/938]
# [Test] Accuracy: 90.0, Avg loss: 0.4851212
# [Model 2] Epochs 19
# -------------------------------
# [Train] loss: 0.0226320 [300/938]
# [Train] loss: 0.0163794 [600/938]
# [Train] loss: 0.0030398 [900/938]
# [Test] Accuracy: 90.4, Avg loss: 0.4869834
# [Model 2] Epochs 20
# -------------------------------
# [Train] loss: 0.0343581 [300/938]
# [Train] loss: 0.0242687 [600/938]
# [Train] loss: 0.0039004 [900/938]
# [Test] Accuracy: 90.5, Avg loss: 0.4919606
# [Model 2] Epochs 21
# -------------------------------
# [Train] loss: 0.0123871 [300/938]
# [Train] loss: 0.0100881 [600/938]
# [Train] loss: 0.0123342 [900/938]
# [Test] Accuracy: 90.2, Avg loss: 0.5653833
# [Model 2] Epochs 22
# -------------------------------
# [Train] loss: 0.0347727 [300/938]
# [Train] loss: 0.0093093 [600/938]
# [Train] loss: 0.0059134 [900/938]
# [Test] Accuracy: 90.1, Avg loss: 0.5047471
# [Model 2] Epochs 23
# -------------------------------
# [Train] loss: 0.0340584 [300/938]
# [Train] loss: 0.0346642 [600/938]
# [Train] loss: 0.0242764 [900/938]
# [Test] Accuracy: 90.4, Avg loss: 0.5337236
# [Model 2] Epochs 24
# -------------------------------
# [Train] loss: 0.0241082 [300/938]
# [Train] loss: 0.0057935 [600/938]
# [Train] loss: 0.0088882 [900/938]
# [Test] Accuracy: 91.0, Avg loss: 0.5183199
# [Model 2] Epochs 25
# -------------------------------
# [Train] loss: 0.0129067 [300/938]
# [Train] loss: 0.0149316 [600/938]
# [Train] loss: 0.0044350 [900/938]
# [Test] Accuracy: 90.8, Avg loss: 0.4997194
# [Model 3] Epochs 1
# -------------------------------
# [Train] loss: 0.6027869 [300/938]
# [Train] loss: 0.3923789 [600/938]
# [Train] loss: 0.2979088 [900/938]
# [Test] Accuracy: 87.4, Avg loss: 0.3392244
# [Model 3] Epochs 2
# -------------------------------
# [Train] loss: 0.2981621 [300/938]
# [Train] loss: 0.3118533 [600/938]
# [Train] loss: 0.1411604 [900/938]
# [Test] Accuracy: 88.7, Avg loss: 0.3034278
# [Model 3] Epochs 3
# -------------------------------
# [Train] loss: 0.3260853 [300/938]
# [Train] loss: 0.2214861 [600/938]
# [Train] loss: 0.1323609 [900/938]
# [Test] Accuracy: 89.4, Avg loss: 0.2893982
# [Model 3] Epochs 4
# -------------------------------
# [Train] loss: 0.2069952 [300/938]
# [Train] loss: 0.2285232 [600/938]
# [Train] loss: 0.1679545 [900/938]
# [Test] Accuracy: 90.8, Avg loss: 0.2490502
# [Model 3] Epochs 5
# -------------------------------
# [Train] loss: 0.1436647 [300/938]
# [Train] loss: 0.1861134 [600/938]
# [Train] loss: 0.1318220 [900/938]
# [Test] Accuracy: 90.8, Avg loss: 0.2508855
# [Model 3] Epochs 6
# -------------------------------
# [Train] loss: 0.2218914 [300/938]
# [Train] loss: 0.1307651 [600/938]
# [Train] loss: 0.1070741 [900/938]
# [Test] Accuracy: 91.1, Avg loss: 0.2479743
# [Model 3] Epochs 7
# -------------------------------
# [Train] loss: 0.1692798 [300/938]
# [Train] loss: 0.1216329 [600/938]
# [Train] loss: 0.0545764 [900/938]
# [Test] Accuracy: 91.6, Avg loss: 0.2356290
# [Model 3] Epochs 8
# -------------------------------
# [Train] loss: 0.1680103 [300/938]
# [Train] loss: 0.1504026 [600/938]
# [Train] loss: 0.1074300 [900/938]
# [Test] Accuracy: 91.6, Avg loss: 0.2306034
# [Model 3] Epochs 9
# -------------------------------
# [Train] loss: 0.1425174 [300/938]
# [Train] loss: 0.1646537 [600/938]
# [Train] loss: 0.0595334 [900/938]
# [Test] Accuracy: 92.0, Avg loss: 0.2299462
# [Model 3] Epochs 10
# -------------------------------
# [Train] loss: 0.1029163 [300/938]
# [Train] loss: 0.0862848 [600/938]
# [Train] loss: 0.0856429 [900/938]
# [Test] Accuracy: 91.9, Avg loss: 0.2256546
# [Model 3] Epochs 11
# -------------------------------
# [Train] loss: 0.0995550 [300/938]
# [Train] loss: 0.1284561 [600/938]
# [Train] loss: 0.1119386 [900/938]
# [Test] Accuracy: 92.1, Avg loss: 0.2247637
# [Model 3] Epochs 12
# -------------------------------
# [Train] loss: 0.0788527 [300/938]
# [Train] loss: 0.1331674 [600/938]
# [Train] loss: 0.1380936 [900/938]
# [Test] Accuracy: 92.4, Avg loss: 0.2143771
# [Model 3] Epochs 13
# -------------------------------
# [Train] loss: 0.1473410 [300/938]
# [Train] loss: 0.1021703 [600/938]
# [Train] loss: 0.0405341 [900/938]
# [Test] Accuracy: 91.9, Avg loss: 0.2178704
# [Model 3] Epochs 14
# -------------------------------
# [Train] loss: 0.1486348 [300/938]
# [Train] loss: 0.1371086 [600/938]
# [Train] loss: 0.0607182 [900/938]
# [Test] Accuracy: 92.3, Avg loss: 0.2129768
# [Model 3] Epochs 15
# -------------------------------
# [Train] loss: 0.0986188 [300/938]
# [Train] loss: 0.0899207 [600/938]
# [Train] loss: 0.0844627 [900/938]
# [Test] Accuracy: 92.5, Avg loss: 0.2135714
# [Model 3] Epochs 16
# -------------------------------
# [Train] loss: 0.1083222 [300/938]
# [Train] loss: 0.1293702 [600/938]
# [Train] loss: 0.0995324 [900/938]
# [Test] Accuracy: 92.9, Avg loss: 0.2093718
# [Model 3] Epochs 17
# -------------------------------
# [Train] loss: 0.1400928 [300/938]
# [Train] loss: 0.1061733 [600/938]
# [Train] loss: 0.0446007 [900/938]
# [Test] Accuracy: 92.6, Avg loss: 0.2159184
# [Model 3] Epochs 18
# -------------------------------
# [Train] loss: 0.1490962 [300/938]
# [Train] loss: 0.1286521 [600/938]
# [Train] loss: 0.0621041 [900/938]
# [Test] Accuracy: 92.6, Avg loss: 0.2133013
# [Model 3] Epochs 19
# -------------------------------
# [Train] loss: 0.1237354 [300/938]
# [Train] loss: 0.0699428 [600/938]
# [Train] loss: 0.0711298 [900/938]
# [Test] Accuracy: 92.0, Avg loss: 0.2262453
# [Model 3] Epochs 20
# -------------------------------
# [Train] loss: 0.0899212 [300/938]
# [Train] loss: 0.1210346 [600/938]
# [Train] loss: 0.0537851 [900/938]
# [Test] Accuracy: 92.2, Avg loss: 0.2128382
# [Model 3] Epochs 21
# -------------------------------
# [Train] loss: 0.1583761 [300/938]
# [Train] loss: 0.1224978 [600/938]
# [Train] loss: 0.0639241 [900/938]
# [Test] Accuracy: 92.3, Avg loss: 0.2220247
# [Model 3] Epochs 22
# -------------------------------
# [Train] loss: 0.1385598 [300/938]
# [Train] loss: 0.1233547 [600/938]
# [Train] loss: 0.0774945 [900/938]
# [Test] Accuracy: 92.4, Avg loss: 0.2155184
# [Model 3] Epochs 23
# -------------------------------
# [Train] loss: 0.1235497 [300/938]
# [Train] loss: 0.1452642 [600/938]
# [Train] loss: 0.0482236 [900/938]
# [Test] Accuracy: 92.8, Avg loss: 0.2036190
# [Model 3] Epochs 24
# -------------------------------
# [Train] loss: 0.1236783 [300/938]
# [Train] loss: 0.0810236 [600/938]
# [Train] loss: 0.0728893 [900/938]
# [Test] Accuracy: 92.9, Avg loss: 0.2063316
# [Model 3] Epochs 25
# -------------------------------
# [Train] loss: 0.0871214 [300/938]
# [Train] loss: 0.1049424 [600/938]
# [Train] loss: 0.1168926 [900/938]
# [Test] Accuracy: 92.7, Avg loss: 0.2104323

# %%
Plots.gr(size=(400,250))
label = ["mlp" "cnn" "cnn2"]
title = "Handwritten Digit Accuracy"
Plots.plot(1:epochs, accuracies, label=label, title=title)
